# %%
#functions

def square(n):
    return(n*n)
x=square(6)
print(x)
# Out:
# 36

# %%
def welcome(name):
    print("Welcome",name)
welcome("Amina")
# Out:
# Welcome Amina

# %%
#Dictionary

car = {"brand":"Toyota","color":"White","year":2024}

print(car["brand"])
print(car["color"])
# Out:
# Toyota
# White
